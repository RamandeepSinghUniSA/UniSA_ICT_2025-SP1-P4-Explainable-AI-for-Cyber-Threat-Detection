# %% [markdown]
# # Binary Ensembler:
# The Binary Ensembler Trains multiple LSTM and Random Forests and stores them in an object. The code preprocesses a dataset for each of the given labels based on a correlation threshold (only applied to categorical features currently). Then it trains a LSTM and Random Forest on each set and prints the evaluations for each label. Has options for
# a downsampled dataset and the full dataset.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
import os
import time
from sklearn.utils.class_weight import compute_class_weight
import random
import shap
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import random

# %%
def plot_metrics(train, val, epochs, title):
    """
    Plot the training, validation, and test metrics.

    Parameters:
        - train_loss (list): Training metric.
        - val_loss (list): Validation metric.
        - test_loss (list): Test tmetric.
        - epochs (int): The number of epochs.
        - title (string): The title of the plot (imputes the category with type of plot).
    """

    sns.set_theme(style="whitegrid", palette="pastel")
    plt.figure(figsize=(6, 4))
    plt.plot(range(1, epochs + 1), train, label='Training', color=sns.color_palette("pastel")[0])
    plt.plot(range(1, epochs + 1), val, label='Validation', color=sns.color_palette("pastel")[1])
    plt.xlabel('Epochs')
    plt.ylabel(f"{title}")
    plt.title(f"{title}")
    plt.legend()
    plt.ylim(bottom=0)
    plt.show()

# %%
class CorrEncoder:
    """
    CorrEncoder: Takes a dataset as input and uses it for the encode function. Encodes the filtered categories then draws correlations.
    If correlation is above the threshold adds it to a new dataframe then returns the one hot encoded values with the labels.

    Initialisation:
        - data (pd.DataFrame): The Dataset that contains the target column and target label variables.
    """
    
    def __init__(self, data):
        self.data = data.copy()
        # Removes Label for the binary processing as it is based on the specific attack_cat.
        self.data = self.data.drop(columns=['Label'])

    def encode(self, target_column, sparse_n, threshold, cat):
        """
        encode: Takes a target column and target label to encode and draw correlations from. The target column is iterated through
        for all categories that contain more positive values than defined in sparse_n. This allows for filtering of sparse categories.
        The function then one hot encodes the given category with the static target column and draws correlations for them. If correlation
        is greater then threshold then add it to the new DataFrame. The function returns the one hot encoded categories that pass the
        threshold with the target label.

        The purpose of this function is to resolve the high cardinality problem in one hot encoding.

        Parameters:
            - target_column (string): The name of the target column. The target column should contain the various categories to encode.
            - sparse_n (integer): The minimum amount of positive values required for a category after encoding (deals with sparse categories).
            - threshold (float): The threshold for correlation. The function creates onehot encoded columns of all variables that high correlation
              higher that the threshold to the target label.
            - cat (string): The category label to compare to.

        Returns:
            - ohe_df (pd.DataFrame): The one hot encoded values from the target columns.
        """

        # Convert to string to handle duplicates.
        self.data[target_column] = self.data[target_column].astype(str)
        value_counts = self.data[target_column].value_counts()
        # Check if number of 1s is above the given threshold set by sparse_n.
        categories = value_counts[value_counts > sparse_n].index.tolist()
        ohe_list = []

        # Convert the target label to one hot encoded.
        attack_cat = (self.data['attack_cat'] == cat).astype(int)
        # Go through each unique category in the target column.
        for c in categories:
            col_name = f'{target_column}_{c}'

            # Create the binary encoding column for the current category and target label
            corr_column = (self.data[target_column] == c).astype(int)
            correlation = corr_column.corr(attack_cat)

            # Check if absolute correlation is greater than threshold.
            if abs(correlation) > threshold:
                corr_column.name = col_name
                ohe_list.append(corr_column)
        if ohe_list:
            # NOTE: This section can be expanded to include print outs but at the moment am focusing on the evaluations.
            ohe_df = pd.concat(ohe_list, axis=1)
            return ohe_df
        else:
            # This ommits errors (if really high thresholds are used).
            print("No correlations exceed the threshold.")
            return pd.DataFrame()

# %%
import pandas as pd
import torch
from torch.utils.data import TensorDataset
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from imblearn.over_sampling import SMOTE  # For SMOTE upsampling
from sklearn.model_selection import train_test_split
import random

class DataSamplerBinary:
    """
    DataSamplerBinary3: Preprocesses data for the LSTM and Random Forest for a given label category. Uses down-sampling with a mask to reduce the Normal labels by a given percentage,
    ensuring that no Normal values adjacent to a threat row are removed. Alternatively uses the full data or upsampling with SMOTE. Preprocesses and encodes the categories by filtering
    categories with correlation below a given threshold. Creates tensors for the LSTM and stores the data for referencing through the ensembler.

    Initialisation:
        - train (None): The attribute that stores the train tensor.
        - val(None): The attribute that stores the train tensor.
        - test (None): The attribute that stores the train tensor.
        - name (string): The name of the label category.
    """
    
    def __init__(self):
        self.train = None
        self.val = None
        self.test = None
        self.name = None

    def get_data(self, type_of, size, rs, category, threshold, downsample_percentage=None, split_method='slice'):
        """
        get_data: Preprocess and transform data for the LSTM and Random Forest. Combines the 4 USNW-NB15 datasets and downsamples the Normal labels by a given percentage,
        ensuring that no Normal values adjacent to a threat row are removed. Alternatively uses the full data or upsampling with SMOTE. One hot encodes the categories using a given
        threshold for correlation through the CorrEncoder class. Scales the data and then splits a train, validation, and test set using either slicing or shuffling. Finally creates
        and returns tensors with an added dimension for the LSTM. The class stores the datasets as attributes for referencing.

        Parameters:
            - type_of (string): The type of preprocessing to use. Options are 'downsample', 'upsample', or 'full'.
            - size (float): The proportion for the validation and test set (same size).
            - rs (int): The random seed to use for the slicing, shuffling, and SMOTE.
            - category (string): The label category to preprocess.
            - threshold (float): The threshold value for the minimum correlation in one hot encoded categories.
            - downsample_percentage (float): The percentage of "Normal" labels to downsample (e.g., 0.5 for 50%). Only used if type_of='downsample'.
            - split_method (string): The method to split the data into train, validation, and test sets. Options are 'slice' (default) or 'shuffle'.
        
        Returns:
            - train_dataset (tensor): The training tensor given as (rows, sequence, features).
            - val_dataset (tensor): The validation tensor given as (rows, sequence, features).
            - test_dataset (tensor): The testing tensor given as (rows, sequence, features).        
        """

        # Combine datasets and preprocess.
        # NOTE: The null values are converted to Normal labels.
        feature_names = pd.read_csv('features2.csv')
        self.name = category
        feature_names_list = feature_names['Name'].tolist()
        s1 = pd.read_csv('UNSW-NB15_1.csv', header=None)
        s1.columns = feature_names_list
        s1.loc[s1['attack_cat'].isnull(), 'attack_cat'] = 'Normal'

        feature_names_list = feature_names['Name'].tolist()
        s2 = pd.read_csv('UNSW-NB15_2.csv', header=None)
        s2.columns = feature_names_list
        s2.loc[s2['attack_cat'].isnull(), 'attack_cat'] = 'Normal'

        feature_names_list = feature_names['Name'].tolist()
        s3 = pd.read_csv('UNSW-NB15_3.csv', header=None)
        s3.columns = feature_names_list
        s3.loc[s3['attack_cat'].isnull(), 'attack_cat'] = 'Normal'

        feature_names_list = feature_names['Name'].tolist()
        s4 = pd.read_csv('UNSW-NB15_4.csv', header=None)
        s4.columns = feature_names_list
        s4.loc[s4['attack_cat'].isnull(), 'attack_cat'] = 'Normal'
        
        i = 0
        data = [s1, s2, s3, s4]
        # If downsampling is chosen, downsample the Normal labels by the given percentage, ensuring no Normal values adjacent to a threat row are removed.
        if type_of == 'downsample' and downsample_percentage is not None:
            while i < len(data):
                df = data[i]
                # Create a mask to identify Normal rows that are NOT adjacent to a threat row.
                mask = (df['Label'].shift(-1) != 1) & (df['Label'].shift(1) != 1)
                normal_rows = df[(df['attack_cat'] == 'Normal') & mask]
                num_to_remove = int(len(normal_rows) * downsample_percentage)
                rows_to_remove = normal_rows.sample(n=num_to_remove, random_state=rs)
                df = df.drop(rows_to_remove.index)
                data[i] = df
                i += 1

        # Combine the datasets
        full_data = pd.concat([data[0], data[1], data[2], data[3]]).reset_index(drop=True)

        # Clean Labels and drop sparse data.
        full_data['attack_cat'] = full_data['attack_cat'].str.replace(r'\s+', '', regex=True)
        full_data['attack_cat'] = full_data['attack_cat'].str.replace('Backdoors', 'Backdoor')
        full_data = full_data.drop(columns=['ct_ftp_cmd', 'ct_flw_http_mthd', 'is_ftp_login'])
        # Clean error values (imported as hex strings for some reason).
        full_data = full_data[~full_data['sport'].astype(str).str.startswith('0x')]
        full_data = full_data[~full_data['sport'].astype(str).str.startswith('-')]
        full_data['sport'] = full_data['sport'].apply(pd.to_numeric)
        full_data = full_data[~full_data['dsport'].astype(str).str.startswith('0x')]
        full_data = full_data[~full_data['dsport'].astype(str).str.startswith('-')]
        full_data['dsport'] = full_data['dsport'].apply(pd.to_numeric)

        columns = ['state', 'service']
        encoder = OneHotEncoder(sparse_output=False, dtype='float32')
        encoded_data = encoder.fit_transform(full_data[columns])
        encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(columns), index=full_data.index)
        full_encoded = pd.concat([full_data.drop(columns=columns), encoded_df], axis=1)
        encoder = CorrEncoder(full_encoded)
        ohe1 = encoder.encode('dsport', 30, threshold, category)
        ohe2 = encoder.encode('proto', 30, threshold, category)
        ohe3 = encoder.encode('sport', 30, threshold, category)
        ohe4 = encoder.encode('srcip', 30, threshold, category)
        ohe5 = encoder.encode('dstip', 30, threshold, category)
        cols_to_drop = ['dsport', 'proto', 'sport', 'srcip', 'dstip']
        filtered_data = full_encoded.drop(columns=cols_to_drop)
        combined_data = pd.concat([filtered_data, ohe1, ohe2, ohe3, ohe4, ohe5], axis=1)
        # NOTE: There is no need for LabelEncoder here as we know threat = 1 and rest = 0.
        combined_data['attack_cat'] = (combined_data['attack_cat'] == category).astype(int)
        df_features = combined_data.drop(columns=['attack_cat', 'Label'])
        scaler = MinMaxScaler()
        scaled_data = scaler.fit_transform(df_features)
        final_data = pd.DataFrame(scaled_data, columns=df_features.columns, index=combined_data.index)
        final_data['attack_cat'] = combined_data['attack_cat']

        random.seed(rs)

        if type_of == 'upsample':
            smote = SMOTE(random_state=rs)
            X_resampled, y_resampled = smote.fit_resample(final_data.drop(columns=['attack_cat']), final_data['attack_cat'])
            final_data = pd.concat([pd.DataFrame(X_resampled, columns=final_data.drop(columns=['attack_cat']).columns),
                                   pd.Series(y_resampled, name='attack_cat')], axis=1)
        if split_method == 'slice':
            slice_size = int(size * len(final_data))
            val_start = random.randrange(0, len(final_data) - 2 * slice_size)
            val_end = val_start + slice_size
            val_data = final_data.iloc[val_start:val_end]
            df = final_data.drop(val_data.index)
            test_start = random.randrange(0, len(df) - slice_size)
            test_end = test_start + slice_size
            test_data = df.iloc[test_start:test_end]
            train_data = df.drop(test_data.index)
        elif split_method == 'shuffle':
            train_data, temp_data = train_test_split(final_data, test_size=2 * size, random_state=rs)
            val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=rs)
        else:
            raise ValueError("Invalid split_method. Choose 'slice' or 'shuffle'.")

        self.train = train_data
        self.val = val_data
        self.test = test_data

        return train_data, val_data, test_data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import torch
#       3 from torch.utils.data import TensorDataset
#       4 from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
#
# File c:\Users\adi_s\anaconda3\envs\conda311new\Lib\site-packages\torch\__init__.py:2118
#    2113         backend = _TorchCompileWrapper(backend, mode, options, dynamic)
#    2115     return torch._dynamo.optimize(backend=backend, nopython=fullgraph, dynamic=dynamic, disable=disable)(model)
# -> 2118 from torch import export as export
#    2120 from torch._higher_order_ops import cond
#    2122 def _register_device_module(device_type, module):
#
# File c:\Users\adi_s\anaconda3\envs\conda311new\Lib\site-packages\torch\export\__init__.py:28
#      25 import torch.utils._pytree as pytree
#      26 from torch.fx._compatibility import compatibility
# ---> 28 from torch.fx.passes.infra.pass_base import PassResult
#      29 from torch.fx.passes.infra.pass_manager import PassManager
#      31 from torch.utils._pytree import (
#      32     FlattenFunc,
#      33     FromDumpableContextFn,
#      34     ToDumpableContextFn,
#      35     UnflattenFunc,
#      36 )
#
# File c:\Users\adi_s\anaconda3\envs\conda311new\Lib\site-packages\torch\fx\passes\__init__.py:6
#       4 from . import operator_support
#       5 from . import param_fetch
# ----> 6 from . import reinplace
#       7 from . import runtime_assert
#       8 from . import shape_prop
#
# File c:\Users\adi_s\anaconda3\envs\conda311new\Lib\site-packages\torch\fx\passes\reinplace.py:5
#       3 from torch.fx import Node
#       4 from torch.fx._compatibility import compatibility
# ----> 5 from torch._subclasses.fake_tensor import FakeTensorMode, FakeTensor
#       6 from torch.utils._pytree import tree_map_only
#       7 from torch.utils import _pytree as pytree
#
# File c:\Users\adi_s\anaconda3\envs\conda311new\Lib\site-packages\torch\_subclasses\__init__.py:3
#       1 import torch
# ----> 3 from torch._subclasses.fake_tensor import (
#       4     DynamicOutputShapeException,
#       5     FakeTensor,
#       6     FakeTensorMode,
#       7     UnsupportedFakeTensorException,
#       8 )
#      10 from torch._subclasses.fake_utils import CrossRefFakeMode
#      12 __all__ = [
#      13     "FakeTensor",
#      14     "FakeTensorMode",
#    (...)
#      17     "CrossRefFakeMode",
#      18 ]
#
# File c:\Users\adi_s\anaconda3\envs\conda311new\Lib\site-packages\torch\_subclasses\fake_tensor.py:2092
#    2079 _DISPATCH_META_HANDLERS = {
#    2080     torch.ops.prim.device.default: _device_handler,
#    2081     torch.ops.aten.size.default: lambda args: tuple(int(s) for s in args[0].size()),
#    2082     torch.ops.aten.stride.default: lambda args: tuple(int(s) for s in args[0].stride()),
#    2083     torch.ops.aten.storage_offset.default: lambda args: int(args[0].storage_offset()),
#    2084 }
#    2086 _DISPATCH_HANDLE_DIRECTLY = ordered_set(
#    2087     torch.ops.aten.is_coalesced.default,
#    2088     torch.ops.aten.dense_dim.default,
#    2089     torch.ops.aten.sparse_dim.default,
#    2090 )
# -> 2092 from torch._subclasses.fake_impls import (  # noqa: F401
#    2093     _device_not_kwarg_ops,  # noqa: F401
#    2094     _is_tensor_constructor,  # noqa: F401
#    2095     _like_tensor_constructors,  # noqa: F401
#    2096     contains_tensor_types,  # noqa: F401
#    2097     get_fast_op_impls,
#    2098     has_meta,
#    2099     op_implementations_checks,
#    2100     stride_incorrect_op,
#    2101 )
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1138, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1078, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1507, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1479, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1615, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
class SimpleNN(nn.Module):
    """
    BinaryFC: A simple Fully Connected neural network with two layers and ReLU activation. 
    Trains and validates the model, then tests it and stores the evaluation metrics as attributes.
    """
    def __init__(self, input_size, hidden_size, device, save_dir, name):
        super(SimpleNN, self).__init__()
        self.name = name
        self.device = device  # Store device (CPU or GPU)
        self.save_dir = save_dir

        # Fully Connected layers
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, 1)  # Single output unit for binary classification
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

        # Move model to the appropriate device (GPU/CPU)
        self.to(self.device)

        # To store loss and metrics
        self.train_loss = []
        self.val_loss = []
        self.train_accuracy = []
        self.val_accuracy = []
        self.train_f1 = []
        self.val_f1 = []
        self.epoch_time = []
        self.test_accuracy = None
        self.test_loss = None
        self.test_f1 = None
        self.test_predicted = []
        self.test_actual = []

    def forward(self, x):
        """
        Forward pass for the Fully Connected model.
        
        Parameters:
            - x (tensor): The input features.
        
        Returns:
            - output (tensor): The output after the second fully connected layer with Sigmoid.
        """
        x = self.relu(self.fc1(x))  # Apply ReLU activation after first fully connected layer
        x = self.fc2(x)  # Apply second fully connected layer
        output = self.sigmoid(x)  # Apply Sigmoid activation to output for binary classification
        return output

    def calculate_accuracy_f1(self, predictions, labels):
        """
        Calculate accuracy and F1 score.
        
        Parameters:
            - predictions (tensor): The predictions given by the model.
            - labels (tensor): The true labels.
        
        Returns:
            - accuracy (float): The accuracy score.
            - f1 (float): The weighted F1 score.
        """
        preds = (predictions > 0.5).float()  # Apply threshold to sigmoid outputs (0.5 for binary)
        accuracy = accuracy_score(labels.cpu(), preds.cpu())  # Calculate accuracy
        f1 = f1_score(labels.cpu(), preds.cpu(), average='weighted')  # Calculate weighted F1 score
        return accuracy, f1

    def run(self, train_data, val_data, test_data, criterion, optimizer, epochs, save_factor):
        """
        Train, validate, and test the model.
        
        Parameters:
            - train_data (TensorDataset): The training dataset (features + labels).
            - val_data (TensorDataset): The validation dataset (features + labels).
            - test_data (TensorDataset): The test dataset (features + labels).
            - criterion (nn.BCEWithLogitsLoss): The loss function for binary classification.
            - optimizer (optim.Adam): The optimizer for training.
            - epochs (int): The number of epochs to train.
            - save_factor (int): The factor at which to save the model during training.
        
        Returns:
            - explainer (shap.GradientExplainer): The SHAP explainer for the test data.
        """
        train_seq, train_label = train_data.tensors
        val_seq, val_label = val_data.tensors
        test_seq, test_label = test_data.tensors

        train_seq, train_label = train_seq.to(self.device), train_label.to(self.device)
        val_seq, val_label = val_seq.to(self.device), val_label.to(self.device)
        test_seq, test_label = test_seq.to(self.device), test_label.to(self.device)

        for epoch in range(epochs):
            start_time = time.time()
            self.train()
            optimizer.zero_grad()

            # Forward pass
            outputs = self(train_seq)
            loss = criterion(outputs.squeeze(), train_label)
            loss.backward()
            optimizer.step()
            train_accuracy, train_f1 = self.calculate_accuracy_f1(outputs, train_label)
            self.eval()
            with torch.no_grad():
                val_outputs = self(val_seq)
                val_loss = criterion(val_outputs.squeeze(), val_label)
                val_accuracy, val_f1 = self.calculate_accuracy_f1(val_outputs, val_label)

            self.train_loss.append(loss.item())
            self.val_loss.append(val_loss.item())
            self.train_accuracy.append(train_accuracy)
            self.val_accuracy.append(val_accuracy)
            self.train_f1.append(train_f1)
            self.val_f1.append(val_f1)

            epoch_time = time.time() - start_time
            self.epoch_time.append(epoch_time)

            print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {loss.item():.4f}, Train Accuracy: {train_accuracy:.4f}, Train F1: {train_f1:.4f}")
            print(f"Val Loss: {val_loss.item():.4f}, Val Accuracy: {val_accuracy:.4f}, Val F1: {val_f1:.4f}")
            if (epoch + 1) % save_factor == 0:
                self.save_model(epoch + 1)
        self.eval()
        with torch.no_grad():
            test_outputs = self(test_seq)
            test_loss = criterion(test_outputs.squeeze(), test_label)
            test_accuracy, test_f1 = self.calculate_accuracy_f1(test_outputs, test_label)
            self.test_accuracy = test_accuracy
            self.test_loss = test_loss.item()
            self.test_f1 = test_f1

            self.test_pred = (torch.sigmoid(test_outputs) > 0.5).cpu().numpy()
            self.test_actual = test_label.cpu().numpy()
            print(f"Test Loss: {self.test_loss:.4f}, Test Accuracy: {self.test_accuracy:.4f}, Test F1: {self.test_f1:.4f}")

        # SHAP explanation using the gradient-based explainer
        explainer = shap.GradientExplainer(self, test_seq)
        return explainer

    def save_model(self, epoch):
        """
        Save the model state_dict for the given epoch.
        
        Parameters:
            - epoch (int): The current epoch.
        """
        checkpoint_path = os.path.join(self.save_dir, f"fc_epoch_{epoch}.pt")
        torch.save({
            'epoch': epoch,
            'model_state_dict': self.state_dict(),
        }, checkpoint_path)

    def load_model(self, epoch):
        """
        Load a state_dict of a model.
        
        Parameters:
            - epoch (int): The epoch to load.
        """
        checkpoint_path = os.path.join(self.save_dir, f"fc_epoch_{epoch}.pt")
        checkpoint = torch.load(checkpoint_path)
        self.load_state_dict(checkpoint['model_state_dict'])

# %%
class BinaryEnsembler:
    """
    BinaryEnsembler: Creates an ensemble of Binary LSTM and Binary Random Forests and stores them as attributes along with the given data. The models are stored as attributes
    allowing referencing to the models attributes.

    Initialisation:
        - 
    """
    def __init__(self, labels, hidden_size, num_layers, epochs, threshold, learning_rate):
        self.labels = labels
        self.data_ensemble = []
        self.model_ensemble = []
        self.explainers_ensemble = []
        self.tree_ensemble = []
        self.model_accuracy = 0
        self.tree_accuracy = 0
        for label in self.labels:
            ds = DataSamplerBinary()
            train_data, val_data, test_data = ds.get_data('downsample', 0.15, 42, label, threshold)
            self.data_ensemble.append(ds)
            device = torch.device("cpu")
            input_size = train_data.tensors[0].shape[2]
            model = BinaryLSTM(input_size, hidden_size, num_layers, device, 'model', label)
            criterion = nn.BCEWithLogitsLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate)
            explainer = model.run(train_data, val_data, test_data, criterion, optimizer, epochs, 50)
            self.model_ensemble.append(model)
            self.explainers_ensemble.append(explainer)
            # All metrics are held within the model and can be called.
            plot_metrics(model.train_loss, model.val_loss, epochs, label + ' Loss')
            plot_metrics(model.train_f1, model.val_f1, epochs, label + ' F1')
            plot_metrics(model.train_accuracy, model.val_accuracy, epochs, label + ' Accuracy')
            # There is only 1 time but omits errors if wanting to just plot 1.
            plot_metrics(model.epoch_time, model.epoch_time, epochs, label + ' Time')
            tr_data, labels = train_data.tensors
            tr_data = tr_data.squeeze()
            tr_data = pd.DataFrame(tr_data)
            tr_data['labels'] = pd.DataFrame(labels)
            te_data, labels = test_data.tensors
            te_data = te_data.squeeze()
            te_data = pd.DataFrame(te_data)
            te_data['labels'] = pd.DataFrame(labels)
            X_train = tr_data.drop(columns='labels')
            y_train = tr_data['labels']
            X_test = te_data.drop(columns='labels')
            y_test = te_data['labels']
            rf = RandomForestClassifier(n_estimators=100, random_state=42)
            rf.fit(X_train, y_train)
            y_pred = rf.predict(X_test)
            accuracy = accuracy_score(y_test, y_pred)
            self.model_accuracy += model.test_accuracy
            self.tree_accuracy += accuracy
            print(f"{label} Accuracy: {accuracy:.4f}")
            print('\nClassification Report:')
            print(classification_report(y_test, y_pred))
        print('Average LSTM Accuracy')
        print(self.model_accuracy/len(self.labels))
        print('Average Random Forest Accuracy')
        print(self.tree_accuracy/len(self.labels))

# %%
labels = ['DoS', 'Fuzzers', 'Generic', 'Exploits', 'Reconnaissance', 'Backdoor', 'Analysis', 'Shellcode', 'Worms']
be = BinaryEnsembler(labels, 128, 1, 100, 0.1, 0.07)
# Out:
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:45: DtypeWarning: Columns (1,3,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s1 = pd.read_csv('UNSW-NB15_1.csv', header=None)
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:50: DtypeWarning: Columns (3,39,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s2 = pd.read_csv('UNSW-NB15_2.csv', header=None)
# Epoch [1/100], Train Loss: 0.7335, Train Accuracy: 0.0336, Train F1: 0.0022
# Val Loss: 0.2213, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [2/100], Train Loss: 0.2502, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0993, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [3/100], Train Loss: 0.1485, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.1188, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [4/100], Train Loss: 0.1796, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.1187, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [5/100], Train Loss: 0.1774, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.1015, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [6/100], Train Loss: 0.1489, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0791, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [7/100], Train Loss: 0.1139, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0669, Val Accuracy: 0.9773, Val F1: 0.9684
# Epoch [8/100], Train Loss: 0.0975, Train Accuracy: 0.9640, Train F1: 0.9534
# Val Loss: 0.0693, Val Accuracy: 0.9625, Val F1: 0.9686
# Epoch [9/100], Train Loss: 0.1038, Train Accuracy: 0.9475, Train F1: 0.9538
# Val Loss: 0.0713, Val Accuracy: 0.9618, Val F1: 0.9684
# Epoch [10/100], Train Loss: 0.1065, Train Accuracy: 0.9417, Train F1: 0.9518
# Val Loss: 0.0701, Val Accuracy: 0.9618, Val F1: 0.9684
# Epoch [11/100], Train Loss: 0.1028, Train Accuracy: 0.9421, Train F1: 0.9520
# Val Loss: 0.0685, Val Accuracy: 0.9628, Val F1: 0.9688
# Epoch [12/100], Train Loss: 0.0986, Train Accuracy: 0.9484, Train F1: 0.9542
# Val Loss: 0.0670, Val Accuracy: 0.9754, Val F1: 0.9699
# Epoch [13/100], Train Loss: 0.0953, Train Accuracy: 0.9615, Train F1: 0.9549
# Val Loss: 0.0653, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [14/100], Train Loss: 0.0926, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0632, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [15/100], Train Loss: 0.0901, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0614, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [16/100], Train Loss: 0.0880, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0601, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [17/100], Train Loss: 0.0867, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0594, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [18/100], Train Loss: 0.0861, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0591, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [19/100], Train Loss: 0.0860, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0591, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [20/100], Train Loss: 0.0861, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0591, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [21/100], Train Loss: 0.0862, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0590, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [22/100], Train Loss: 0.0862, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0587, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [23/100], Train Loss: 0.0858, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0584, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [24/100], Train Loss: 0.0853, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0580, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [25/100], Train Loss: 0.0847, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0577, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [26/100], Train Loss: 0.0842, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0575, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [27/100], Train Loss: 0.0839, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0576, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [28/100], Train Loss: 0.0838, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0577, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [29/100], Train Loss: 0.0838, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0578, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [30/100], Train Loss: 0.0838, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0578, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [31/100], Train Loss: 0.0838, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0576, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [32/100], Train Loss: 0.0835, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0573, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [33/100], Train Loss: 0.0832, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0570, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [34/100], Train Loss: 0.0830, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0568, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [35/100], Train Loss: 0.0828, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0567, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [36/100], Train Loss: 0.0827, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0566, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [37/100], Train Loss: 0.0827, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0566, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [38/100], Train Loss: 0.0827, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0566, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [39/100], Train Loss: 0.0827, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0565, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [40/100], Train Loss: 0.0827, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0565, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [41/100], Train Loss: 0.0826, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0564, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [42/100], Train Loss: 0.0824, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0563, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [43/100], Train Loss: 0.0823, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0563, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [44/100], Train Loss: 0.0822, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0562, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [45/100], Train Loss: 0.0821, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0562, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [46/100], Train Loss: 0.0820, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0562, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [47/100], Train Loss: 0.0820, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0562, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [48/100], Train Loss: 0.0819, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0561, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [49/100], Train Loss: 0.0819, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0561, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [50/100], Train Loss: 0.0818, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0560, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [51/100], Train Loss: 0.0817, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0559, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [52/100], Train Loss: 0.0816, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0558, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [53/100], Train Loss: 0.0815, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0557, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [54/100], Train Loss: 0.0815, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0557, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [55/100], Train Loss: 0.0814, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0557, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [56/100], Train Loss: 0.0814, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0556, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [57/100], Train Loss: 0.0813, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0556, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [58/100], Train Loss: 0.0812, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0555, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [59/100], Train Loss: 0.0812, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0555, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [60/100], Train Loss: 0.0811, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0555, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [61/100], Train Loss: 0.0810, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0555, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [62/100], Train Loss: 0.0810, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0554, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [63/100], Train Loss: 0.0809, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0554, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [64/100], Train Loss: 0.0809, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0554, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [65/100], Train Loss: 0.0808, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0553, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [66/100], Train Loss: 0.0808, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0553, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [67/100], Train Loss: 0.0807, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0552, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [68/100], Train Loss: 0.0807, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0552, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [69/100], Train Loss: 0.0806, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0551, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [70/100], Train Loss: 0.0806, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0551, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [71/100], Train Loss: 0.0805, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0551, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [72/100], Train Loss: 0.0805, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0550, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [73/100], Train Loss: 0.0804, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0550, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [74/100], Train Loss: 0.0804, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0550, Val Accuracy: 0.9781, Val F1: 0.9672
# Epoch [75/100], Train Loss: 0.0803, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0550, Val Accuracy: 0.9781, Val F1: 0.9672
# Epoch [76/100], Train Loss: 0.0803, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0550, Val Accuracy: 0.9781, Val F1: 0.9672
# Epoch [77/100], Train Loss: 0.0802, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0549, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [78/100], Train Loss: 0.0802, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0549, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [79/100], Train Loss: 0.0802, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0549, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [80/100], Train Loss: 0.0801, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0548, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [81/100], Train Loss: 0.0801, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0548, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [82/100], Train Loss: 0.0800, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0548, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [83/100], Train Loss: 0.0800, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0547, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [84/100], Train Loss: 0.0800, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0547, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [85/100], Train Loss: 0.0799, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0547, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [86/100], Train Loss: 0.0799, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0547, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [87/100], Train Loss: 0.0798, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0547, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [88/100], Train Loss: 0.0798, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0546, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [89/100], Train Loss: 0.0798, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0546, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [90/100], Train Loss: 0.0797, Train Accuracy: 0.9664, Train F1: 0.9499
# Val Loss: 0.0546, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [91/100], Train Loss: 0.0797, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0546, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [92/100], Train Loss: 0.0797, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0545, Val Accuracy: 0.9780, Val F1: 0.9672
# Epoch [93/100], Train Loss: 0.0796, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0545, Val Accuracy: 0.9780, Val F1: 0.9673
# Epoch [94/100], Train Loss: 0.0796, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0545, Val Accuracy: 0.9780, Val F1: 0.9673
# Epoch [95/100], Train Loss: 0.0796, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0545, Val Accuracy: 0.9780, Val F1: 0.9673
# Epoch [96/100], Train Loss: 0.0795, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0544, Val Accuracy: 0.9780, Val F1: 0.9673
# Epoch [97/100], Train Loss: 0.0795, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0544, Val Accuracy: 0.9780, Val F1: 0.9673
# Epoch [98/100], Train Loss: 0.0795, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0544, Val Accuracy: 0.9781, Val F1: 0.9673
# Epoch [99/100], Train Loss: 0.0794, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0544, Val Accuracy: 0.9781, Val F1: 0.9673
# Epoch [100/100], Train Loss: 0.0794, Train Accuracy: 0.9664, Train F1: 0.9500
# Val Loss: 0.0543, Val Accuracy: 0.9781, Val F1: 0.9673
# Test Loss: 0.0587, Test Accuracy: 0.9757, Test F1: 0.9638
# DoS Accuracy: 0.9764
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99     78550
#          1.0       0.89      0.03      0.06      1954
#
#     accuracy                           0.98     80504
#    macro avg       0.93      0.52      0.53     80504
# weighted avg       0.97      0.98      0.97     80504
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:45: DtypeWarning: Columns (1,3,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s1 = pd.read_csv('UNSW-NB15_1.csv', header=None)
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:50: DtypeWarning: Columns (3,39,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s2 = pd.read_csv('UNSW-NB15_2.csv', header=None)
# Epoch [1/100], Train Loss: 0.6754, Train Accuracy: 0.9511, Train F1: 0.9274
# Val Loss: 0.2077, Val Accuracy: 0.9617, Val F1: 0.9429
# Epoch [2/100], Train Loss: 0.2253, Train Accuracy: 0.9510, Train F1: 0.9271
# Val Loss: 0.1954, Val Accuracy: 0.9617, Val F1: 0.9429
# Epoch [3/100], Train Loss: 0.2352, Train Accuracy: 0.9510, Train F1: 0.9271
# Val Loss: 0.1975, Val Accuracy: 0.9617, Val F1: 0.9429
# Epoch [4/100], Train Loss: 0.2369, Train Accuracy: 0.9510, Train F1: 0.9271
# Val Loss: 0.1499, Val Accuracy: 0.9617, Val F1: 0.9429
# Epoch [5/100], Train Loss: 0.1770, Train Accuracy: 0.9510, Train F1: 0.9271
# Val Loss: 0.1108, Val Accuracy: 0.9618, Val F1: 0.9431
# Epoch [6/100], Train Loss: 0.1268, Train Accuracy: 0.9539, Train F1: 0.9344
# Val Loss: 0.1556, Val Accuracy: 0.9624, Val F1: 0.9634
# Epoch [7/100], Train Loss: 0.1694, Train Accuracy: 0.9484, Train F1: 0.9509
# Val Loss: 0.1163, Val Accuracy: 0.9725, Val F1: 0.9714
# Epoch [8/100], Train Loss: 0.1296, Train Accuracy: 0.9634, Train F1: 0.9628
# Val Loss: 0.0865, Val Accuracy: 0.9671, Val F1: 0.9568
# Epoch [9/100], Train Loss: 0.0978, Train Accuracy: 0.9633, Train F1: 0.9546
# Val Loss: 0.0831, Val Accuracy: 0.9621, Val F1: 0.9441
# Epoch [10/100], Train Loss: 0.0933, Train Accuracy: 0.9557, Train F1: 0.9383
# Val Loss: 0.0847, Val Accuracy: 0.9622, Val F1: 0.9448
# Epoch [11/100], Train Loss: 0.0942, Train Accuracy: 0.9556, Train F1: 0.9382
# Val Loss: 0.0818, Val Accuracy: 0.9643, Val F1: 0.9507
# Epoch [12/100], Train Loss: 0.0900, Train Accuracy: 0.9588, Train F1: 0.9450
# Val Loss: 0.0745, Val Accuracy: 0.9672, Val F1: 0.9577
# Epoch [13/100], Train Loss: 0.0817, Train Accuracy: 0.9641, Train F1: 0.9559
# Val Loss: 0.0684, Val Accuracy: 0.9724, Val F1: 0.9688
# Epoch [14/100], Train Loss: 0.0759, Train Accuracy: 0.9705, Train F1: 0.9674
# Val Loss: 0.0676, Val Accuracy: 0.9772, Val F1: 0.9770
# Epoch [15/100], Train Loss: 0.0763, Train Accuracy: 0.9760, Train F1: 0.9757
# Val Loss: 0.0667, Val Accuracy: 0.9795, Val F1: 0.9801
# Epoch [16/100], Train Loss: 0.0745, Train Accuracy: 0.9770, Train F1: 0.9773
# Val Loss: 0.0625, Val Accuracy: 0.9809, Val F1: 0.9813
# Epoch [17/100], Train Loss: 0.0673, Train Accuracy: 0.9797, Train F1: 0.9797
# Val Loss: 0.0587, Val Accuracy: 0.9819, Val F1: 0.9821
# Epoch [18/100], Train Loss: 0.0610, Train Accuracy: 0.9817, Train F1: 0.9815
# Val Loss: 0.0575, Val Accuracy: 0.9817, Val F1: 0.9819
# Epoch [19/100], Train Loss: 0.0587, Train Accuracy: 0.9823, Train F1: 0.9820
# Val Loss: 0.0580, Val Accuracy: 0.9811, Val F1: 0.9811
# Epoch [20/100], Train Loss: 0.0590, Train Accuracy: 0.9826, Train F1: 0.9822
# Val Loss: 0.0587, Val Accuracy: 0.9807, Val F1: 0.9807
# Epoch [21/100], Train Loss: 0.0598, Train Accuracy: 0.9825, Train F1: 0.9820
# Val Loss: 0.0588, Val Accuracy: 0.9807, Val F1: 0.9806
# Epoch [22/100], Train Loss: 0.0598, Train Accuracy: 0.9824, Train F1: 0.9819
# Val Loss: 0.0583, Val Accuracy: 0.9810, Val F1: 0.9810
# Epoch [23/100], Train Loss: 0.0590, Train Accuracy: 0.9827, Train F1: 0.9823
# Val Loss: 0.0577, Val Accuracy: 0.9815, Val F1: 0.9816
# Epoch [24/100], Train Loss: 0.0580, Train Accuracy: 0.9830, Train F1: 0.9826
# Val Loss: 0.0571, Val Accuracy: 0.9819, Val F1: 0.9821
# Epoch [25/100], Train Loss: 0.0570, Train Accuracy: 0.9834, Train F1: 0.9831
# Val Loss: 0.0565, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [26/100], Train Loss: 0.0559, Train Accuracy: 0.9835, Train F1: 0.9833
# Val Loss: 0.0555, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [27/100], Train Loss: 0.0546, Train Accuracy: 0.9837, Train F1: 0.9835
# Val Loss: 0.0544, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [28/100], Train Loss: 0.0533, Train Accuracy: 0.9838, Train F1: 0.9836
# Val Loss: 0.0532, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [29/100], Train Loss: 0.0520, Train Accuracy: 0.9838, Train F1: 0.9835
# Val Loss: 0.0522, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [30/100], Train Loss: 0.0511, Train Accuracy: 0.9839, Train F1: 0.9836
# Val Loss: 0.0516, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [31/100], Train Loss: 0.0506, Train Accuracy: 0.9838, Train F1: 0.9835
# Val Loss: 0.0514, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [32/100], Train Loss: 0.0505, Train Accuracy: 0.9837, Train F1: 0.9834
# Val Loss: 0.0514, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [33/100], Train Loss: 0.0504, Train Accuracy: 0.9837, Train F1: 0.9834
# Val Loss: 0.0514, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [34/100], Train Loss: 0.0502, Train Accuracy: 0.9837, Train F1: 0.9834
# Val Loss: 0.0515, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [35/100], Train Loss: 0.0498, Train Accuracy: 0.9837, Train F1: 0.9834
# Val Loss: 0.0515, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [36/100], Train Loss: 0.0494, Train Accuracy: 0.9838, Train F1: 0.9835
# Val Loss: 0.0515, Val Accuracy: 0.9821, Val F1: 0.9823
# Epoch [37/100], Train Loss: 0.0490, Train Accuracy: 0.9839, Train F1: 0.9836
# Val Loss: 0.0514, Val Accuracy: 0.9821, Val F1: 0.9823
# Epoch [38/100], Train Loss: 0.0486, Train Accuracy: 0.9839, Train F1: 0.9836
# Val Loss: 0.0510, Val Accuracy: 0.9821, Val F1: 0.9823
# Epoch [39/100], Train Loss: 0.0481, Train Accuracy: 0.9839, Train F1: 0.9836
# Val Loss: 0.0506, Val Accuracy: 0.9821, Val F1: 0.9823
# Epoch [40/100], Train Loss: 0.0477, Train Accuracy: 0.9839, Train F1: 0.9837
# Val Loss: 0.0502, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [41/100], Train Loss: 0.0473, Train Accuracy: 0.9840, Train F1: 0.9837
# Val Loss: 0.0498, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [42/100], Train Loss: 0.0471, Train Accuracy: 0.9841, Train F1: 0.9838
# Val Loss: 0.0496, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [43/100], Train Loss: 0.0470, Train Accuracy: 0.9841, Train F1: 0.9838
# Val Loss: 0.0494, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [44/100], Train Loss: 0.0469, Train Accuracy: 0.9842, Train F1: 0.9839
# Val Loss: 0.0493, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [45/100], Train Loss: 0.0467, Train Accuracy: 0.9842, Train F1: 0.9839
# Val Loss: 0.0492, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [46/100], Train Loss: 0.0465, Train Accuracy: 0.9842, Train F1: 0.9840
# Val Loss: 0.0491, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [47/100], Train Loss: 0.0463, Train Accuracy: 0.9842, Train F1: 0.9840
# Val Loss: 0.0489, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [48/100], Train Loss: 0.0461, Train Accuracy: 0.9842, Train F1: 0.9840
# Val Loss: 0.0488, Val Accuracy: 0.9820, Val F1: 0.9822
# Epoch [49/100], Train Loss: 0.0459, Train Accuracy: 0.9842, Train F1: 0.9840
# Val Loss: 0.0486, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [50/100], Train Loss: 0.0457, Train Accuracy: 0.9842, Train F1: 0.9840
# Val Loss: 0.0486, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [51/100], Train Loss: 0.0456, Train Accuracy: 0.9842, Train F1: 0.9840
# Val Loss: 0.0486, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [52/100], Train Loss: 0.0455, Train Accuracy: 0.9843, Train F1: 0.9840
# Val Loss: 0.0487, Val Accuracy: 0.9820, Val F1: 0.9823
# Epoch [53/100], Train Loss: 0.0454, Train Accuracy: 0.9843, Train F1: 0.9840
# Val Loss: 0.0487, Val Accuracy: 0.9821, Val F1: 0.9823
# Epoch [54/100], Train Loss: 0.0453, Train Accuracy: 0.9843, Train F1: 0.9840
# Val Loss: 0.0488, Val Accuracy: 0.9821, Val F1: 0.9823
# Epoch [55/100], Train Loss: 0.0451, Train Accuracy: 0.9843, Train F1: 0.9840
# Val Loss: 0.0489, Val Accuracy: 0.9821, Val F1: 0.9823
# Epoch [56/100], Train Loss: 0.0450, Train Accuracy: 0.9843, Train F1: 0.9840
# Val Loss: 0.0489, Val Accuracy: 0.9821, Val F1: 0.9824
# Epoch [57/100], Train Loss: 0.0449, Train Accuracy: 0.9843, Train F1: 0.9841
# Val Loss: 0.0488, Val Accuracy: 0.9821, Val F1: 0.9824
# Epoch [58/100], Train Loss: 0.0448, Train Accuracy: 0.9843, Train F1: 0.9841
# Val Loss: 0.0486, Val Accuracy: 0.9822, Val F1: 0.9825
# Epoch [59/100], Train Loss: 0.0447, Train Accuracy: 0.9843, Train F1: 0.9841
# Val Loss: 0.0484, Val Accuracy: 0.9822, Val F1: 0.9825
# Epoch [60/100], Train Loss: 0.0446, Train Accuracy: 0.9843, Train F1: 0.9841
# Val Loss: 0.0482, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [61/100], Train Loss: 0.0446, Train Accuracy: 0.9843, Train F1: 0.9841
# Val Loss: 0.0481, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [62/100], Train Loss: 0.0445, Train Accuracy: 0.9843, Train F1: 0.9841
# Val Loss: 0.0480, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [63/100], Train Loss: 0.0444, Train Accuracy: 0.9844, Train F1: 0.9842
# Val Loss: 0.0479, Val Accuracy: 0.9823, Val F1: 0.9826
# Epoch [64/100], Train Loss: 0.0444, Train Accuracy: 0.9844, Train F1: 0.9842
# Val Loss: 0.0480, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [65/100], Train Loss: 0.0443, Train Accuracy: 0.9844, Train F1: 0.9842
# Val Loss: 0.0480, Val Accuracy: 0.9823, Val F1: 0.9826
# Epoch [66/100], Train Loss: 0.0442, Train Accuracy: 0.9844, Train F1: 0.9842
# Val Loss: 0.0480, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [67/100], Train Loss: 0.0442, Train Accuracy: 0.9843, Train F1: 0.9842
# Val Loss: 0.0480, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [68/100], Train Loss: 0.0441, Train Accuracy: 0.9843, Train F1: 0.9842
# Val Loss: 0.0480, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [69/100], Train Loss: 0.0441, Train Accuracy: 0.9843, Train F1: 0.9841
# Val Loss: 0.0480, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [70/100], Train Loss: 0.0440, Train Accuracy: 0.9843, Train F1: 0.9841
# Val Loss: 0.0480, Val Accuracy: 0.9822, Val F1: 0.9826
# Epoch [71/100], Train Loss: 0.0439, Train Accuracy: 0.9843, Train F1: 0.9842
# Val Loss: 0.0480, Val Accuracy: 0.9823, Val F1: 0.9827
# Epoch [72/100], Train Loss: 0.0439, Train Accuracy: 0.9844, Train F1: 0.9842
# Val Loss: 0.0480, Val Accuracy: 0.9823, Val F1: 0.9827
# Epoch [73/100], Train Loss: 0.0438, Train Accuracy: 0.9844, Train F1: 0.9843
# Val Loss: 0.0479, Val Accuracy: 0.9823, Val F1: 0.9827
# Epoch [74/100], Train Loss: 0.0437, Train Accuracy: 0.9845, Train F1: 0.9843
# Val Loss: 0.0477, Val Accuracy: 0.9822, Val F1: 0.9827
# Epoch [75/100], Train Loss: 0.0437, Train Accuracy: 0.9846, Train F1: 0.9844
# Val Loss: 0.0477, Val Accuracy: 0.9823, Val F1: 0.9828
# Epoch [76/100], Train Loss: 0.0436, Train Accuracy: 0.9846, Train F1: 0.9845
# Val Loss: 0.0476, Val Accuracy: 0.9823, Val F1: 0.9828
# Epoch [77/100], Train Loss: 0.0435, Train Accuracy: 0.9846, Train F1: 0.9845
# Val Loss: 0.0477, Val Accuracy: 0.9824, Val F1: 0.9828
# Epoch [78/100], Train Loss: 0.0435, Train Accuracy: 0.9846, Train F1: 0.9845
# Val Loss: 0.0477, Val Accuracy: 0.9824, Val F1: 0.9828
# Epoch [79/100], Train Loss: 0.0434, Train Accuracy: 0.9846, Train F1: 0.9845
# Val Loss: 0.0478, Val Accuracy: 0.9824, Val F1: 0.9828
# Epoch [80/100], Train Loss: 0.0433, Train Accuracy: 0.9847, Train F1: 0.9846
# Val Loss: 0.0478, Val Accuracy: 0.9824, Val F1: 0.9828
# Epoch [81/100], Train Loss: 0.0432, Train Accuracy: 0.9846, Train F1: 0.9845
# Val Loss: 0.0478, Val Accuracy: 0.9824, Val F1: 0.9828
# Epoch [82/100], Train Loss: 0.0432, Train Accuracy: 0.9847, Train F1: 0.9846
# Val Loss: 0.0477, Val Accuracy: 0.9824, Val F1: 0.9828
# Epoch [83/100], Train Loss: 0.0431, Train Accuracy: 0.9847, Train F1: 0.9846
# Val Loss: 0.0477, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [84/100], Train Loss: 0.0431, Train Accuracy: 0.9847, Train F1: 0.9846
# Val Loss: 0.0476, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [85/100], Train Loss: 0.0430, Train Accuracy: 0.9847, Train F1: 0.9846
# Val Loss: 0.0475, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [86/100], Train Loss: 0.0429, Train Accuracy: 0.9848, Train F1: 0.9847
# Val Loss: 0.0474, Val Accuracy: 0.9825, Val F1: 0.9830
# Epoch [87/100], Train Loss: 0.0428, Train Accuracy: 0.9848, Train F1: 0.9847
# Val Loss: 0.0473, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [88/100], Train Loss: 0.0428, Train Accuracy: 0.9848, Train F1: 0.9847
# Val Loss: 0.0473, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [89/100], Train Loss: 0.0427, Train Accuracy: 0.9848, Train F1: 0.9847
# Val Loss: 0.0473, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [90/100], Train Loss: 0.0426, Train Accuracy: 0.9849, Train F1: 0.9847
# Val Loss: 0.0474, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [91/100], Train Loss: 0.0426, Train Accuracy: 0.9849, Train F1: 0.9848
# Val Loss: 0.0474, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [92/100], Train Loss: 0.0425, Train Accuracy: 0.9849, Train F1: 0.9848
# Val Loss: 0.0473, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [93/100], Train Loss: 0.0424, Train Accuracy: 0.9849, Train F1: 0.9848
# Val Loss: 0.0473, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [94/100], Train Loss: 0.0424, Train Accuracy: 0.9849, Train F1: 0.9848
# Val Loss: 0.0472, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [95/100], Train Loss: 0.0423, Train Accuracy: 0.9849, Train F1: 0.9848
# Val Loss: 0.0471, Val Accuracy: 0.9826, Val F1: 0.9830
# Epoch [96/100], Train Loss: 0.0422, Train Accuracy: 0.9850, Train F1: 0.9848
# Val Loss: 0.0471, Val Accuracy: 0.9826, Val F1: 0.9830
# Epoch [97/100], Train Loss: 0.0421, Train Accuracy: 0.9850, Train F1: 0.9849
# Val Loss: 0.0470, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [98/100], Train Loss: 0.0421, Train Accuracy: 0.9850, Train F1: 0.9849
# Val Loss: 0.0470, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [99/100], Train Loss: 0.0420, Train Accuracy: 0.9850, Train F1: 0.9849
# Val Loss: 0.0470, Val Accuracy: 0.9825, Val F1: 0.9829
# Epoch [100/100], Train Loss: 0.0419, Train Accuracy: 0.9850, Train F1: 0.9849
# Val Loss: 0.0470, Val Accuracy: 0.9825, Val F1: 0.9829
# Test Loss: 0.0428, Test Accuracy: 0.9835, Test F1: 0.9839
# Fuzzers Accuracy: 0.9865
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99     77746
#          1.0       0.76      0.88      0.82      2758
#
#     accuracy                           0.99     80504
#    macro avg       0.88      0.93      0.90     80504
# weighted avg       0.99      0.99      0.99     80504
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:45: DtypeWarning: Columns (1,3,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s1 = pd.read_csv('UNSW-NB15_1.csv', header=None)
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:50: DtypeWarning: Columns (3,39,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s2 = pd.read_csv('UNSW-NB15_2.csv', header=None)
# Epoch [1/100], Train Loss: 0.6993, Train Accuracy: 0.3768, Train F1: 0.2062
# Val Loss: 0.3307, Val Accuracy: 0.9211, Val F1: 0.9207
# Epoch [2/100], Train Loss: 0.3309, Train Accuracy: 0.9133, Train F1: 0.9143
# Val Loss: 0.1227, Val Accuracy: 0.9473, Val F1: 0.9472
# Epoch [3/100], Train Loss: 0.1806, Train Accuracy: 0.9199, Train F1: 0.9208
# Val Loss: 0.1669, Val Accuracy: 0.9844, Val F1: 0.9844
# Epoch [4/100], Train Loss: 0.1099, Train Accuracy: 0.9824, Train F1: 0.9823
# Val Loss: 0.4148, Val Accuracy: 0.7696, Val F1: 0.7578
# Epoch [5/100], Train Loss: 0.1322, Train Accuracy: 0.9798, Train F1: 0.9797
# Val Loss: 0.1173, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [6/100], Train Loss: 0.1171, Train Accuracy: 0.9850, Train F1: 0.9850
# Val Loss: 0.0826, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [7/100], Train Loss: 0.1126, Train Accuracy: 0.9859, Train F1: 0.9859
# Val Loss: 0.0806, Val Accuracy: 0.9892, Val F1: 0.9892
# Epoch [8/100], Train Loss: 0.1120, Train Accuracy: 0.9857, Train F1: 0.9856
# Val Loss: 0.0776, Val Accuracy: 0.9889, Val F1: 0.9889
# Epoch [9/100], Train Loss: 0.1092, Train Accuracy: 0.9845, Train F1: 0.9844
# Val Loss: 0.0719, Val Accuracy: 0.9889, Val F1: 0.9889
# Epoch [10/100], Train Loss: 0.0999, Train Accuracy: 0.9853, Train F1: 0.9853
# Val Loss: 0.0641, Val Accuracy: 0.9889, Val F1: 0.9889
# Epoch [11/100], Train Loss: 0.0876, Train Accuracy: 0.9858, Train F1: 0.9858
# Val Loss: 0.0555, Val Accuracy: 0.9892, Val F1: 0.9892
# Epoch [12/100], Train Loss: 0.0754, Train Accuracy: 0.9864, Train F1: 0.9864
# Val Loss: 0.0475, Val Accuracy: 0.9906, Val F1: 0.9906
# Epoch [13/100], Train Loss: 0.0643, Train Accuracy: 0.9872, Train F1: 0.9871
# Val Loss: 0.0413, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [14/100], Train Loss: 0.0557, Train Accuracy: 0.9876, Train F1: 0.9876
# Val Loss: 0.0386, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [15/100], Train Loss: 0.0513, Train Accuracy: 0.9877, Train F1: 0.9877
# Val Loss: 0.0408, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [16/100], Train Loss: 0.0526, Train Accuracy: 0.9878, Train F1: 0.9877
# Val Loss: 0.0471, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [17/100], Train Loss: 0.0581, Train Accuracy: 0.9879, Train F1: 0.9879
# Val Loss: 0.0521, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [18/100], Train Loss: 0.0625, Train Accuracy: 0.9880, Train F1: 0.9880
# Val Loss: 0.0509, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [19/100], Train Loss: 0.0615, Train Accuracy: 0.9881, Train F1: 0.9880
# Val Loss: 0.0452, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [20/100], Train Loss: 0.0565, Train Accuracy: 0.9881, Train F1: 0.9880
# Val Loss: 0.0399, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [21/100], Train Loss: 0.0516, Train Accuracy: 0.9881, Train F1: 0.9880
# Val Loss: 0.0370, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [22/100], Train Loss: 0.0487, Train Accuracy: 0.9880, Train F1: 0.9880
# Val Loss: 0.0360, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [23/100], Train Loss: 0.0479, Train Accuracy: 0.9880, Train F1: 0.9880
# Val Loss: 0.0362, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [24/100], Train Loss: 0.0482, Train Accuracy: 0.9880, Train F1: 0.9880
# Val Loss: 0.0368, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [25/100], Train Loss: 0.0489, Train Accuracy: 0.9880, Train F1: 0.9880
# Val Loss: 0.0372, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [26/100], Train Loss: 0.0493, Train Accuracy: 0.9880, Train F1: 0.9880
# Val Loss: 0.0373, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [27/100], Train Loss: 0.0494, Train Accuracy: 0.9880, Train F1: 0.9880
# Val Loss: 0.0370, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [28/100], Train Loss: 0.0489, Train Accuracy: 0.9881, Train F1: 0.9881
# Val Loss: 0.0363, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [29/100], Train Loss: 0.0480, Train Accuracy: 0.9882, Train F1: 0.9882
# Val Loss: 0.0354, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [30/100], Train Loss: 0.0469, Train Accuracy: 0.9883, Train F1: 0.9882
# Val Loss: 0.0345, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [31/100], Train Loss: 0.0459, Train Accuracy: 0.9883, Train F1: 0.9882
# Val Loss: 0.0338, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [32/100], Train Loss: 0.0452, Train Accuracy: 0.9883, Train F1: 0.9883
# Val Loss: 0.0333, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [33/100], Train Loss: 0.0449, Train Accuracy: 0.9884, Train F1: 0.9884
# Val Loss: 0.0331, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [34/100], Train Loss: 0.0449, Train Accuracy: 0.9884, Train F1: 0.9884
# Val Loss: 0.0330, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [35/100], Train Loss: 0.0450, Train Accuracy: 0.9884, Train F1: 0.9884
# Val Loss: 0.0330, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [36/100], Train Loss: 0.0451, Train Accuracy: 0.9885, Train F1: 0.9884
# Val Loss: 0.0329, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [37/100], Train Loss: 0.0450, Train Accuracy: 0.9885, Train F1: 0.9885
# Val Loss: 0.0328, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [38/100], Train Loss: 0.0448, Train Accuracy: 0.9885, Train F1: 0.9885
# Val Loss: 0.0326, Val Accuracy: 0.9914, Val F1: 0.9914
# Epoch [39/100], Train Loss: 0.0444, Train Accuracy: 0.9885, Train F1: 0.9885
# Val Loss: 0.0324, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [40/100], Train Loss: 0.0439, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0323, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [41/100], Train Loss: 0.0436, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0322, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [42/100], Train Loss: 0.0433, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0323, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [43/100], Train Loss: 0.0432, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0324, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [44/100], Train Loss: 0.0431, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0325, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [45/100], Train Loss: 0.0431, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0325, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [46/100], Train Loss: 0.0431, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0325, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [47/100], Train Loss: 0.0429, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0324, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [48/100], Train Loss: 0.0428, Train Accuracy: 0.9886, Train F1: 0.9885
# Val Loss: 0.0322, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [49/100], Train Loss: 0.0426, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0321, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [50/100], Train Loss: 0.0424, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0320, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [51/100], Train Loss: 0.0423, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0318, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [52/100], Train Loss: 0.0422, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0317, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [53/100], Train Loss: 0.0421, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0316, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [54/100], Train Loss: 0.0420, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0316, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [55/100], Train Loss: 0.0419, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0315, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [56/100], Train Loss: 0.0419, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0315, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [57/100], Train Loss: 0.0418, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0315, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [58/100], Train Loss: 0.0417, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0315, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [59/100], Train Loss: 0.0416, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0315, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [60/100], Train Loss: 0.0415, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0315, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [61/100], Train Loss: 0.0414, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0316, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [62/100], Train Loss: 0.0413, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0316, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [63/100], Train Loss: 0.0413, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0317, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [64/100], Train Loss: 0.0412, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0317, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [65/100], Train Loss: 0.0412, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0317, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [66/100], Train Loss: 0.0411, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0316, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [67/100], Train Loss: 0.0410, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0316, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [68/100], Train Loss: 0.0410, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0315, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [69/100], Train Loss: 0.0409, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0314, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [70/100], Train Loss: 0.0408, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0314, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [71/100], Train Loss: 0.0408, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [72/100], Train Loss: 0.0407, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [73/100], Train Loss: 0.0407, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [74/100], Train Loss: 0.0406, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [75/100], Train Loss: 0.0406, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [76/100], Train Loss: 0.0405, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [77/100], Train Loss: 0.0405, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [78/100], Train Loss: 0.0404, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [79/100], Train Loss: 0.0404, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [80/100], Train Loss: 0.0404, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [81/100], Train Loss: 0.0403, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [82/100], Train Loss: 0.0403, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [83/100], Train Loss: 0.0402, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [84/100], Train Loss: 0.0402, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [85/100], Train Loss: 0.0401, Train Accuracy: 0.9886, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [86/100], Train Loss: 0.0401, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0313, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [87/100], Train Loss: 0.0400, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [88/100], Train Loss: 0.0400, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [89/100], Train Loss: 0.0399, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [90/100], Train Loss: 0.0399, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [91/100], Train Loss: 0.0398, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [92/100], Train Loss: 0.0398, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [93/100], Train Loss: 0.0397, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [94/100], Train Loss: 0.0397, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [95/100], Train Loss: 0.0397, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0312, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [96/100], Train Loss: 0.0396, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0311, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [97/100], Train Loss: 0.0396, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0311, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [98/100], Train Loss: 0.0395, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0311, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [99/100], Train Loss: 0.0395, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0311, Val Accuracy: 0.9915, Val F1: 0.9915
# Epoch [100/100], Train Loss: 0.0395, Train Accuracy: 0.9887, Train F1: 0.9886
# Val Loss: 0.0310, Val Accuracy: 0.9915, Val F1: 0.9915
# Test Loss: 0.0356, Test Accuracy: 0.9901, Test F1: 0.9901
# Generic Accuracy: 0.9936
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99     47593
#          1.0       1.00      0.99      0.99     32911
#
#     accuracy                           0.99     80504
#    macro avg       0.99      0.99      0.99     80504
# weighted avg       0.99      0.99      0.99     80504
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:45: DtypeWarning: Columns (1,3,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s1 = pd.read_csv('UNSW-NB15_1.csv', header=None)
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:50: DtypeWarning: Columns (3,39,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s2 = pd.read_csv('UNSW-NB15_2.csv', header=None)
# Epoch [1/100], Train Loss: 0.7065, Train Accuracy: 0.0955, Train F1: 0.0475
# Val Loss: 0.2349, Val Accuracy: 0.9498, Val F1: 0.9254
# Epoch [2/100], Train Loss: 0.3158, Train Accuracy: 0.9083, Train F1: 0.8646
# Val Loss: 0.1897, Val Accuracy: 0.9498, Val F1: 0.9254
# Epoch [3/100], Train Loss: 0.3356, Train Accuracy: 0.9083, Train F1: 0.8646
# Val Loss: 0.1362, Val Accuracy: 0.9498, Val F1: 0.9254
# Epoch [4/100], Train Loss: 0.2205, Train Accuracy: 0.9090, Train F1: 0.8665
# Val Loss: 0.2515, Val Accuracy: 0.8798, Val F1: 0.9076
# Epoch [5/100], Train Loss: 0.2994, Train Accuracy: 0.8303, Train F1: 0.8586
# Val Loss: 0.1387, Val Accuracy: 0.9602, Val F1: 0.9567
# Epoch [6/100], Train Loss: 0.1993, Train Accuracy: 0.9120, Train F1: 0.9086
# Val Loss: 0.1106, Val Accuracy: 0.9505, Val F1: 0.9278
# Epoch [7/100], Train Loss: 0.1810, Train Accuracy: 0.9098, Train F1: 0.8698
# Val Loss: 0.1245, Val Accuracy: 0.9500, Val F1: 0.9258
# Epoch [8/100], Train Loss: 0.2015, Train Accuracy: 0.9088, Train F1: 0.8661
# Val Loss: 0.1248, Val Accuracy: 0.9501, Val F1: 0.9261
# Epoch [9/100], Train Loss: 0.2009, Train Accuracy: 0.9085, Train F1: 0.8672
# Val Loss: 0.1116, Val Accuracy: 0.9504, Val F1: 0.9284
# Epoch [10/100], Train Loss: 0.1843, Train Accuracy: 0.9054, Train F1: 0.8811
# Val Loss: 0.0985, Val Accuracy: 0.9514, Val F1: 0.9318
# Epoch [11/100], Train Loss: 0.1697, Train Accuracy: 0.9006, Train F1: 0.8915
# Val Loss: 0.0940, Val Accuracy: 0.9527, Val F1: 0.9415
# Epoch [12/100], Train Loss: 0.1647, Train Accuracy: 0.9035, Train F1: 0.9011
# Val Loss: 0.0966, Val Accuracy: 0.9574, Val F1: 0.9527
# Epoch [13/100], Train Loss: 0.1660, Train Accuracy: 0.9075, Train F1: 0.9097
# Val Loss: 0.1006, Val Accuracy: 0.9603, Val F1: 0.9584
# Epoch [14/100], Train Loss: 0.1678, Train Accuracy: 0.9096, Train F1: 0.9140
# Val Loss: 0.1022, Val Accuracy: 0.9607, Val F1: 0.9594
# Epoch [15/100], Train Loss: 0.1671, Train Accuracy: 0.9109, Train F1: 0.9150
# Val Loss: 0.1006, Val Accuracy: 0.9611, Val F1: 0.9594
# Epoch [16/100], Train Loss: 0.1641, Train Accuracy: 0.9124, Train F1: 0.9151
# Val Loss: 0.0971, Val Accuracy: 0.9608, Val F1: 0.9581
# Epoch [17/100], Train Loss: 0.1602, Train Accuracy: 0.9173, Train F1: 0.9143
# Val Loss: 0.0935, Val Accuracy: 0.9588, Val F1: 0.9537
# Epoch [18/100], Train Loss: 0.1569, Train Accuracy: 0.9205, Train F1: 0.9051
# Val Loss: 0.0905, Val Accuracy: 0.9559, Val F1: 0.9463
# Epoch [19/100], Train Loss: 0.1548, Train Accuracy: 0.9176, Train F1: 0.8944
# Val Loss: 0.0882, Val Accuracy: 0.9543, Val F1: 0.9424
# Epoch [20/100], Train Loss: 0.1537, Train Accuracy: 0.9163, Train F1: 0.8892
# Val Loss: 0.0866, Val Accuracy: 0.9534, Val F1: 0.9400
# Epoch [21/100], Train Loss: 0.1532, Train Accuracy: 0.9156, Train F1: 0.8864
# Val Loss: 0.0854, Val Accuracy: 0.9536, Val F1: 0.9403
# Epoch [22/100], Train Loss: 0.1527, Train Accuracy: 0.9157, Train F1: 0.8866
# Val Loss: 0.0842, Val Accuracy: 0.9544, Val F1: 0.9424
# Epoch [23/100], Train Loss: 0.1518, Train Accuracy: 0.9165, Train F1: 0.8895
# Val Loss: 0.0825, Val Accuracy: 0.9568, Val F1: 0.9475
# Epoch [24/100], Train Loss: 0.1500, Train Accuracy: 0.9187, Train F1: 0.8959
# Val Loss: 0.0806, Val Accuracy: 0.9599, Val F1: 0.9541
# Epoch [25/100], Train Loss: 0.1475, Train Accuracy: 0.9212, Train F1: 0.9034
# Val Loss: 0.0790, Val Accuracy: 0.9627, Val F1: 0.9601
# Epoch [26/100], Train Loss: 0.1451, Train Accuracy: 0.9245, Train F1: 0.9120
# Val Loss: 0.0779, Val Accuracy: 0.9651, Val F1: 0.9636
# Epoch [27/100], Train Loss: 0.1433, Train Accuracy: 0.9265, Train F1: 0.9166
# Val Loss: 0.0776, Val Accuracy: 0.9677, Val F1: 0.9678
# Epoch [28/100], Train Loss: 0.1423, Train Accuracy: 0.9289, Train F1: 0.9221
# Val Loss: 0.0774, Val Accuracy: 0.9667, Val F1: 0.9673
# Epoch [29/100], Train Loss: 0.1419, Train Accuracy: 0.9283, Train F1: 0.9226
# Val Loss: 0.0765, Val Accuracy: 0.9667, Val F1: 0.9674
# Epoch [30/100], Train Loss: 0.1410, Train Accuracy: 0.9282, Train F1: 0.9229
# Val Loss: 0.0750, Val Accuracy: 0.9675, Val F1: 0.9681
# Epoch [31/100], Train Loss: 0.1395, Train Accuracy: 0.9293, Train F1: 0.9239
# Val Loss: 0.0733, Val Accuracy: 0.9683, Val F1: 0.9687
# Epoch [32/100], Train Loss: 0.1377, Train Accuracy: 0.9301, Train F1: 0.9243
# Val Loss: 0.0721, Val Accuracy: 0.9686, Val F1: 0.9685
# Epoch [33/100], Train Loss: 0.1364, Train Accuracy: 0.9304, Train F1: 0.9234
# Val Loss: 0.0713, Val Accuracy: 0.9678, Val F1: 0.9671
# Epoch [34/100], Train Loss: 0.1356, Train Accuracy: 0.9298, Train F1: 0.9215
# Val Loss: 0.0705, Val Accuracy: 0.9676, Val F1: 0.9668
# Epoch [35/100], Train Loss: 0.1346, Train Accuracy: 0.9298, Train F1: 0.9213
# Val Loss: 0.0694, Val Accuracy: 0.9684, Val F1: 0.9678
# Epoch [36/100], Train Loss: 0.1334, Train Accuracy: 0.9304, Train F1: 0.9221
# Val Loss: 0.0683, Val Accuracy: 0.9693, Val F1: 0.9690
# Epoch [37/100], Train Loss: 0.1321, Train Accuracy: 0.9310, Train F1: 0.9235
# Val Loss: 0.0676, Val Accuracy: 0.9696, Val F1: 0.9694
# Epoch [38/100], Train Loss: 0.1311, Train Accuracy: 0.9313, Train F1: 0.9243
# Val Loss: 0.0670, Val Accuracy: 0.9696, Val F1: 0.9696
# Epoch [39/100], Train Loss: 0.1303, Train Accuracy: 0.9316, Train F1: 0.9250
# Val Loss: 0.0664, Val Accuracy: 0.9696, Val F1: 0.9696
# Epoch [40/100], Train Loss: 0.1294, Train Accuracy: 0.9316, Train F1: 0.9249
# Val Loss: 0.0654, Val Accuracy: 0.9702, Val F1: 0.9698
# Epoch [41/100], Train Loss: 0.1283, Train Accuracy: 0.9316, Train F1: 0.9242
# ...
# Epoch [92/100], Train Loss: 0.0121, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0232, Val Accuracy: 0.9951, Val F1: 0.9927
# Epoch [93/100], Train Loss: 0.0121, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0232, Val Accuracy: 0.9951, Val F1: 0.9927
# Epoch [94/100], Train Loss: 0.0121, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0231, Val Accuracy: 0.9951, Val F1: 0.9927
# Epoch [95/100], Train Loss: 0.0120, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0231, Val Accuracy: 0.9951, Val F1: 0.9927
# Epoch [96/100], Train Loss: 0.0120, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0231, Val Accuracy: 0.9951, Val F1: 0.9927
# Epoch [97/100], Train Loss: 0.0120, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0230, Val Accuracy: 0.9951, Val F1: 0.9927
# Epoch [98/100], Train Loss: 0.0120, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0230, Val Accuracy: 0.9951, Val F1: 0.9927
# Epoch [99/100], Train Loss: 0.0119, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0230, Val Accuracy: 0.9951, Val F1: 0.9927
# Epoch [100/100], Train Loss: 0.0119, Train Accuracy: 0.9975, Train F1: 0.9963
# Val Loss: 0.0229, Val Accuracy: 0.9951, Val F1: 0.9927
# Test Loss: 0.0114, Test Accuracy: 0.9976, Test F1: 0.9963
# Shellcode Accuracy: 0.9982
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     80307
#          1.0       0.77      0.37      0.50       197
#
#     accuracy                           1.00     80504
#    macro avg       0.88      0.69      0.75     80504
# weighted avg       1.00      1.00      1.00     80504
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:45: DtypeWarning: Columns (1,3,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s1 = pd.read_csv('UNSW-NB15_1.csv', header=None)
# C:\Users\adi_s\AppData\Local\Temp\ipykernel_5844\753908975.py:50: DtypeWarning: Columns (3,39,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   s2 = pd.read_csv('UNSW-NB15_2.csv', header=None)
# No correlations exceed the threshold.
# No correlations exceed the threshold.
# No correlations exceed the threshold.
# No correlations exceed the threshold.
# No correlations exceed the threshold.
# Epoch [1/100], Train Loss: 0.6837, Train Accuracy: 0.8433, Train F1: 0.9146
# Val Loss: 0.1535, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [2/100], Train Loss: 0.1675, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0077, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [3/100], Train Loss: 0.0108, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0022, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [4/100], Train Loss: 0.0036, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0024, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [5/100], Train Loss: 0.0040, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0029, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [6/100], Train Loss: 0.0048, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0033, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [7/100], Train Loss: 0.0054, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0036, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [8/100], Train Loss: 0.0060, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0039, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [9/100], Train Loss: 0.0065, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0042, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [10/100], Train Loss: 0.0069, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0044, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [11/100], Train Loss: 0.0072, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0046, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [12/100], Train Loss: 0.0075, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0047, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [13/100], Train Loss: 0.0078, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0049, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [14/100], Train Loss: 0.0081, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0050, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [15/100], Train Loss: 0.0083, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0051, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [16/100], Train Loss: 0.0084, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0052, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [17/100], Train Loss: 0.0086, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0053, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [18/100], Train Loss: 0.0087, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0054, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [19/100], Train Loss: 0.0089, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0054, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [20/100], Train Loss: 0.0090, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0055, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [21/100], Train Loss: 0.0091, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0055, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [22/100], Train Loss: 0.0091, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [23/100], Train Loss: 0.0092, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [24/100], Train Loss: 0.0093, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [25/100], Train Loss: 0.0093, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [26/100], Train Loss: 0.0093, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [27/100], Train Loss: 0.0094, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0057, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [28/100], Train Loss: 0.0094, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0057, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [29/100], Train Loss: 0.0094, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0057, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [30/100], Train Loss: 0.0094, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0057, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [31/100], Train Loss: 0.0094, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [32/100], Train Loss: 0.0094, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [33/100], Train Loss: 0.0093, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [34/100], Train Loss: 0.0093, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [35/100], Train Loss: 0.0093, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [36/100], Train Loss: 0.0092, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0056, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [37/100], Train Loss: 0.0092, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0055, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [38/100], Train Loss: 0.0091, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0055, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [39/100], Train Loss: 0.0091, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0055, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [40/100], Train Loss: 0.0090, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0054, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [41/100], Train Loss: 0.0090, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0054, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [42/100], Train Loss: 0.0089, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0053, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [43/100], Train Loss: 0.0088, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0053, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [44/100], Train Loss: 0.0087, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0052, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [45/100], Train Loss: 0.0086, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0052, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [46/100], Train Loss: 0.0085, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0051, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [47/100], Train Loss: 0.0084, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0051, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [48/100], Train Loss: 0.0084, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0050, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [49/100], Train Loss: 0.0083, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0049, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [50/100], Train Loss: 0.0082, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0049, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [51/100], Train Loss: 0.0081, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0048, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [52/100], Train Loss: 0.0080, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0048, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [53/100], Train Loss: 0.0079, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0047, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [54/100], Train Loss: 0.0078, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0046, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [55/100], Train Loss: 0.0077, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0046, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [56/100], Train Loss: 0.0076, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0045, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [57/100], Train Loss: 0.0075, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0045, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [58/100], Train Loss: 0.0074, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0044, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [59/100], Train Loss: 0.0073, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0044, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [60/100], Train Loss: 0.0072, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0043, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [61/100], Train Loss: 0.0071, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0043, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [62/100], Train Loss: 0.0071, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0042, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [63/100], Train Loss: 0.0070, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0042, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [64/100], Train Loss: 0.0069, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0041, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [65/100], Train Loss: 0.0068, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0041, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [66/100], Train Loss: 0.0068, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0040, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [67/100], Train Loss: 0.0067, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0040, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [68/100], Train Loss: 0.0066, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0039, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [69/100], Train Loss: 0.0065, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0039, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [70/100], Train Loss: 0.0064, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0038, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [71/100], Train Loss: 0.0064, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0038, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [72/100], Train Loss: 0.0063, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0037, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [73/100], Train Loss: 0.0062, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0037, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [74/100], Train Loss: 0.0061, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0036, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [75/100], Train Loss: 0.0060, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0036, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [76/100], Train Loss: 0.0060, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0035, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [77/100], Train Loss: 0.0059, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0035, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [78/100], Train Loss: 0.0058, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0034, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [79/100], Train Loss: 0.0057, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0034, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [80/100], Train Loss: 0.0056, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0033, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [81/100], Train Loss: 0.0055, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0033, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [82/100], Train Loss: 0.0054, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0032, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [83/100], Train Loss: 0.0053, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0032, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [84/100], Train Loss: 0.0053, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0031, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [85/100], Train Loss: 0.0052, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0031, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [86/100], Train Loss: 0.0051, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0030, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [87/100], Train Loss: 0.0050, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0030, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [88/100], Train Loss: 0.0049, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0029, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [89/100], Train Loss: 0.0049, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0029, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [90/100], Train Loss: 0.0048, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0028, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [91/100], Train Loss: 0.0047, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0028, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [92/100], Train Loss: 0.0046, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0027, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [93/100], Train Loss: 0.0046, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0027, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [94/100], Train Loss: 0.0045, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0027, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [95/100], Train Loss: 0.0044, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0026, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [96/100], Train Loss: 0.0043, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0026, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [97/100], Train Loss: 0.0043, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0025, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [98/100], Train Loss: 0.0042, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0025, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [99/100], Train Loss: 0.0041, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0024, Val Accuracy: 0.9998, Val F1: 0.9997
# Epoch [100/100], Train Loss: 0.0041, Train Accuracy: 0.9996, Train F1: 0.9995
# Val Loss: 0.0024, Val Accuracy: 0.9998, Val F1: 0.9997
# Test Loss: 0.0035, Test Accuracy: 0.9997, Test F1: 0.9995
# Worms Accuracy: 0.9997
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     80479
#          1.0       0.33      0.12      0.18        25
#
#     accuracy                           1.00     80504
#    macro avg       0.67      0.56      0.59     80504
# weighted avg       1.00      1.00      1.00     80504
#
# Average LSTM Accuracy
# 0.9865693354091446
# Average Random Forest Accuracy
# 0.9884477789923483
